# %%
import pandas as pd

# %%
assault_csv_path='Resources/Assault.csv'
BnE_csv_path='Resources/Break_and_Enter.csv'
TfV_csv_path='Resources/Theft_from_Motor_Vehicle.csv'

# %%
assault_df=pd.read_csv(assault_csv_path)
BnE_df=pd.read_csv(BnE_csv_path)
TfV_df=pd.read_csv(TfV_csv_path)
# Out:
# C:\Users\lintu\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3186: DtypeWarning: Columns (0,1,2,3,5,7,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
assault_df.head()
# Out:
#   event_unique_id          occurrencedate  \
# 0  GO-20141260128  2014/01/01 05:00:00+00
# 1  GO-20141259483  2013/12/31 05:00:00+00
# 2  GO-20141260137  2014/01/01 05:00:00+00
# 3  GO-20141259767  2014/01/01 05:00:00+00
# 4  GO-20141259762  2013/12/31 05:00:00+00
#
#                                        location_type premises_type  \
# 0  Single Home, House (Attach Garage, Cottage, Mo...         House
# 1                                   Ttc Subway Train       Transit
# 2                                 Ttc Subway Station       Transit
# 3  Streets, Roads, Highways (Bicycle Path, Privat...       Outside
# 4                                   Bar / Restaurant    Commercial
#
#    occurrenceyear occurrencemonth  occurrenceday occurrencedayofweek  \
# 0          2014.0         January            1.0          Wednesday
# 1          2013.0        December           31.0          Tuesday
# 2          2014.0         January            1.0          Wednesday
# 3          2014.0         January            1.0          Wednesday
# 4          2013.0        December           31.0          Tuesday
#
#    occurrencehour mci_category                      Neighbourhood  Longitude  \
# 0             1.0      Assault                  Rockcliffe-Smythe -79.480268
# 1            21.0      Assault                Bay Street Corridor -79.386589
# 2             1.0      Assault                              Annex -79.411749
# 3             2.0      Assault  Waterfront Communities-The Island -79.392819
# 4            23.0      Assault  Waterfront Communities-The Island -79.390756
#
#     Latitude
# 0  43.683360
# 1  43.650853
# 2  43.666620
# 3  43.647320
# 4  43.649131
